# %%
import os
import pandas

# %%
files = os.listdir('car_wale')

# %%
for file in files:
# Out:
# ['carwale (ahmda).csv',
#  'carwale (chandighar).csv',
#  'carwale (chenaai).csv',
#  'carwale (d+h).csv',
#  'carwale (dheili).csv',
#  'carwale (kolkatta).csv',
#  'carwale.csv',
#  'carwale_real_data copy.csv']
